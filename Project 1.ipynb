# %%
# setup the environment
# %pylab inline

import pandas as pd
import seaborn as sns
from __future__ import division
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.mpl_style = 'default'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# get the data
stmath = pd.read_csv('../stmath.csv', index_col=(0,1,2))

print len(stmath), 'observations'
print

print stmath.head()
print 

stmath.describe()
# Out:
# 1620 observations
#
#                                     cumulative_progress  cumulative_mastery  total_classroom_logins  total_home_logins  total_minutes_logged  SGP_MAP_Winter_Math
# student_id school_name grade_level
# 1772736543 TEAM        5                             81                  80                     102                 24                  2226                   11
# 1722457445 TEAM        5                             27                  25                      46                 21                   941                   42
# 1978548017 SPARK       4                              6                   5                      61                  1                  2100                   87
# 1583235855 SPARK       4                             45                  32                      88                 22                  1530                   40
# 671436847  TEAM        5                             90                  82                     157                 23                  2688                    0
#        cumulative_progress  cumulative_mastery  total_classroom_logins  total_home_logins  total_minutes_logged  SGP_MAP_Winter_Math
# count          1620.000000         1620.000000             1620.000000        1620.000000           1620.000000          1620.000000
# mean             48.185185           42.914815               65.300617           9.584568           3396.702469            52.447531
# std              39.575031           37.614591               34.873995          19.776194           4262.679062            36.809834
# min               0.000000            0.000000                1.000000           0.000000              0.000000             0.000000
# 25%              22.000000           18.000000               41.000000           0.000000           1126.000000            15.000000
# 50%              39.000000           34.000000               62.000000           2.000000           1773.500000            54.000000
# 75%              59.000000           55.000000               86.000000           9.000000           3875.000000            91.000000
# max             325.000000          307.000000              226.000000         211.000000          37302.000000           100.000000

# %% [markdown]
# ## Data definitions
# | Feature | Type | Definition |
# |-------|:----:|------------|
# | **student_id** | Discrete | A unique identifer for each student |
# | **school_name** | Discrete | A student's current school (academic year 2014-2015) |
# | **grade_level** | Discrete | A student's current grade-level (academic year 2014-2015) |
# | **cumulative_progress** | Continuous | The percentage completion that a student has achieved in their assigned ST Math grade-level module. If a student has completed a module and proceeded on to the next grade, it can be above 100. |
# | **cumulative_mastery** | Continuous | Similiar to *cumulative_progress*, but inclusive of a student's "mastery" in their module's subject matter. If a student has completed a module and proceeded on to the next grade, it can be above 100. |
# | **total_classroom_logins** | Continuous | The number of logins that a student has made at school |
# | **total_home_logins** | Continuous | The number of logins that a student has made at home |
# | **total_minutes logged** | Continuous | The total number of minutes a student has spent on the program, includes idle time |
# | **SGP_MAP_Winter_Math (target variable)** | Continuous | A student's growth percentile from their baseline to winter score on the MAP math assessment. |

# %%
## everyone
cols = ['cumulative_progress','cumulative_mastery','total_classroom_logins','total_home_logins','total_minutes_logged','SGP_MAP_Winter_Math']
pd.scatter_matrix(stmath[cols], figsize=(24,24), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0efdd1e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0efb06150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0efb3bb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef9ed490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef970610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef8d5510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef856850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef824ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef7c1250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef744090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef6a4ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef626e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef58c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef50fc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef5c7850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef482590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef4047d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef368a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef2e9d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef2c4510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef1d3650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef155490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef145290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef0c7410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0ef07fd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eef8ddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eef10b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eeeff890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eee81ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eede9750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eed69a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eeda1510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eec5b410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eebdf590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eebc38d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0eeb44c10>]], dtype=object)
# /home/vagrant/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1279: UserWarning: findfont: Font family [u'monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## NOTES GO HERE
# - SGP is bimodal, should analyze it separately by students above and below 50th percentile
# - a lot of features have exponential-looking distributions (home logins & minutes)
# - show cleaning steps in python
# - dive deeper into how individual variables contribute to SGP
# - look into variables' relationships with one another

# %%
## create a couple new fields for subsetting
stmath['minutes_per_login'] = (stmath['total_minutes_logged'] * 1.0 / (stmath['total_classroom_logins'] + stmath['total_home_logins'])).round(-1)

# %%
stmath.head()
# Out:
#                                     cumulative_progress  cumulative_mastery  total_classroom_logins  total_home_logins  total_minutes_logged  SGP_MAP_Winter_Math  minutes_per_login
# student_id school_name grade_level
# 1772736543 TEAM        5                             81                  80                     102                 24                  2226                   11                 20
# 1722457445 TEAM        5                             27                  25                      46                 21                   941                   42                 10
# 1978548017 SPARK       4                              6                   5                      61                  1                  2100                   87                 30
# 1583235855 SPARK       4                             45                  32                      88                 22                  1530                   40                 10
# 671436847  TEAM        5                             90                  82                     157                 23                  2688                    0                 10
